# %% [markdown]
# <a href="https://colab.research.google.com/github/vkartikey/AirBNB-EDA-Analysis/blob/main/EDA_Proj_first_draft.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("/content/drive/MyDrive/Airbnb NYC 2019.csv")

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
print(df.nunique())
# Out:
# id                                48895
# name                              47905
# host_id                           37457
# host_name                         11452
# neighbourhood_group                   5
# neighbourhood                       221
# latitude                          19048
# longitude                         14718
# room_type                             3
# price                               674
# minimum_nights                      109
# number_of_reviews                   394
# last_review                        1764
# reviews_per_month                   937
# calculated_host_listings_count       47
# availability_365                    366
# dtype: int64

# %%
df.shape
# Out:
# (48895, 16)

# %%
df.isnull().any()
# Out:
# id                                False
# name                               True
# host_id                           False
# host_name                          True
# neighbourhood_group               False
# neighbourhood                     False
# latitude                          False
# longitude                         False
# room_type                         False
# price                             False
# minimum_nights                    False
# number_of_reviews                 False
# last_review                        True
# reviews_per_month                  True
# calculated_host_listings_count    False
# availability_365                  False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.sort_values("availability_365", ascending = True).head(40)
#df.sort_values(by='host_name', ascending=False, na_position='first').head(30)
# Out:
#              id                                               name    host_id  \
# 24447  19677284                               Room in Williamsburg   63336737
# 14080  10774325                       Convenient Studio Apartment!    3068641
# 14079  10773150                Upper East Side Little Private Room   55725808
# 28719  22205765  Beautiful spacious Greenwich Village apt w/ ga...   16798487
# 28720  22205780  Spacious Brooklyn apartment with yard, roof ac...   67753773
# 14076  10771369                          Awesome Midtown Get-A-Way   55713233
# 14075  10770836                             Upper West Side Studio   55709707
# 28721  22206164            Sleek and Hip Lower East Side 2 Bedroom    3452920
# 14073  10766339                    Gorgeous 2BR by Brooklyn Museum    9358748
# 28723  22206345                      1 Bedroom/ 1 Bath in Bushwick   32345243
# 14071  10765607                      Great location • Cozy • Clean     243427
# ...

# %%
a = (df[df["availability_365"]==0])
a
# Out:
#              id                                               name    host_id  \
# 4          5022   Entire Apt: Spacious Studio/Loft by central park       7192
# 6          5121                                    BlissArtsSpace!       7356
# 8          5203                 Cozy Clean Guest Room - Family Apt       7490
# 14         6090                      West Village Nest - Superhost      11975
# 20         7801                   Sweet and Spacious Brooklyn Loft      21207
# ...         ...                                                ...        ...
# 48550  36313048    Sunny room with private entrance in shared home   16883913
# 48731  36410519    Sunlight charming apt. in the heart of Brooklyn  121384174
# 48756  36419441                            Murray Hill Masterpiece  273824202
# 48760  36420725  Sunnyside, Queens 15 Mins to Midtown Clean & C...   19990280
# 48779  36424776  Queen size bedroom in two bed apt with great l...   13384464
#
# ...

# %%
a.sort_values('last_review', ascending = False)
# Out:
#              id                                               name    host_id  \
# 18988  15082723   Williamsburg Private Room, Outdoor Space w/grill   33677512
# 43699  33810599   Furnished modern studio luxury elevator building   28175069
# 40830  31714168                                5 min away from LGA  213014559
# 44287  34151215               Bright and Artsy 2 Bedroom Apartment  257810280
# 35528  28202825   Feel at home in NYC, 5 min from LGA With PARKING  213014559
# ...         ...                                                ...        ...
# 48550  36313048    Sunny room with private entrance in shared home   16883913
# 48731  36410519    Sunlight charming apt. in the heart of Brooklyn  121384174
# 48756  36419441                            Murray Hill Masterpiece  273824202
# 48760  36420725  Sunnyside, Queens 15 Mins to Midtown Clean & C...   19990280
# 48779  36424776  Queen size bedroom in two bed apt with great l...   13384464
#
# ...

# %%
df.sort_values('minimum_nights', ascending = False).head(20)
# Out:
#              id                                               name    host_id  \
# 5767    4204302                   Prime W. Village location 1 bdrm   17550546
# 2854    1615764                                                NaN    6676776
# 38664  30378211                       Shared Studio (females only)  200401254
# 13404  10053943                 Historic Designer 2 Bed. Apartment    2697686
# 26341  20990053                    Beautiful place in Brooklyn! #2  151084261
# 47620  35834935                             Williamsburg Apartment   82674375
# 14285  11096888                    Peaceful apartment close to F/G    2228137
# 8014    6169897                          Wonderful Large 1 bedroom   10720264
# 11193   8668115                 Zen Room in Crown Heights Brooklyn    8996336
# 7355    5431845                Beautiful Fully Furnished 1 bed/bth    3680008
# 10829   8341919                Brand New Luxury Apt Lease Takeover   43945071
# ...

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
sns.set(rc={'figure.figsize':(9, 3)})

# %%
sns.boxplot(x = 'price', data = df)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
len(df[df["price"] > 900])
# Out:
# 353

# %%
df['neighbourhood_group'].unique()
# Out:
# array(['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
#       dtype=object)

# %%
corr = df.corr( method = "kendall")
fig =plt.figure(figsize=(12,6))
sns.heatmap(corr, annot = True)
#airbnb.columns
# Out:
# <ipython-input-51-463de9b503bd>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df.corr( method = "kendall")
# <Axes: >

# %%
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df1=df.copy()

# %%
df1.drop(['latitude', 'longitude', 'last_review', 'reviews_per_month', 'calculated_host_listings_count'], axis = 1, inplace = True)
df1.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood        room_type  price  \
# 0         John            Brooklyn    Kensington     Private room    149
# 1     Jennifer           Manhattan       Midtown  Entire home/apt    225
# 2    Elisabeth           Manhattan        Harlem     Private room    150
# 3  LisaRoxanne            Brooklyn  Clinton Hill  Entire home/apt     89
# 4        Laura           Manhattan   East Harlem  Entire home/apt     80
#
#    minimum_nights  number_of_reviews  availability_365
# 0               1                  9               365
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   48895 non-null  int64
#  1   name                 48879 non-null  object
#  2   host_id              48895 non-null  int64
#  3   host_name            48874 non-null  object
#  4   neighbourhood_group  48895 non-null  object
#  5   neighbourhood        48895 non-null  object
#  6   room_type            48895 non-null  object
#  7   price                48895 non-null  int64
#  8   minimum_nights       48895 non-null  int64
#  9   number_of_reviews    48895 non-null  int64
#  10  availability_365     48895 non-null  int64
# dtypes: int64(6), object(5)
# memory usage: 4.1+ MB

# %%
df1.describe()
# Out:
#                  id       host_id         price  minimum_nights  \
# count  4.889500e+04  4.889500e+04  48895.000000    48895.000000
# mean   1.901714e+07  6.762001e+07    152.720687        7.029962
# std    1.098311e+07  7.861097e+07    240.154170       20.510550
# min    2.539000e+03  2.438000e+03      0.000000        1.000000
# 25%    9.471945e+06  7.822033e+06     69.000000        1.000000
# 50%    1.967728e+07  3.079382e+07    106.000000        3.000000
# 75%    2.915218e+07  1.074344e+08    175.000000        5.000000
# max    3.648724e+07  2.743213e+08  10000.000000     1250.000000
#
#        number_of_reviews  availability_365
# count       48895.000000      48895.000000
# mean           23.274466        112.781327
# std            44.550582        131.622289
# min             0.000000          0.000000
# 25%             1.000000          0.000000
# 50%             5.000000         45.000000
# 75%            24.000000        227.000000
# ...

# %%
df1.shape
# Out:
# (48895, 11)

# %%
df1.isnull().sum()
# Out:
# id                      0
# name                   16
# host_id                 0
# host_name              21
# neighbourhood_group     0
# neighbourhood           0
# room_type               0
# price                   0
# minimum_nights          0
# number_of_reviews       0
# availability_365        0
# dtype: int64

# %%
df1.dropna(inplace = True)
df1.isnull().sum()
# Out:
# id                     0
# name                   0
# host_id                0
# host_name              0
# neighbourhood_group    0
# neighbourhood          0
# room_type              0
# price                  0
# minimum_nights         0
# number_of_reviews      0
# availability_365       0
# dtype: int64

# %%
sns.histplot(df['price'])
plt.show()

# %%
sns.barplot(df1, x = 'room_type', y = 'price')
# Out:
# <Axes: xlabel='room_type', ylabel='price'>

# %%
sns.scatterplot(data = df1, x = 'availability_365', y = 'price')
# Out:
# <Axes: xlabel='availability_365', ylabel='price'>

# %%
corr = df1.corr( method = "kendall")
fig =plt.figure(figsize=(12,6))
sns.heatmap(corr, annot = True)
#airbnb.columns
# Out:
# <ipython-input-71-728aa4127b7a>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = df1.corr( method = "kendall")
# <Axes: >

# %%
sns.pairplot(df1,dropna = True)

# %%
df1.head(1)
# Out:
#      id                                name  host_id host_name  \
# 0  2539  Clean & quiet apt home by the park     2787      John
#
#   neighbourhood_group neighbourhood     room_type  price  minimum_nights  \
# 0            Brooklyn    Kensington  Private room    149               1
#
#    number_of_reviews  availability_365
# 0                  9               365

# %%
sns.histplot(data=df1, x='room_type')
# Out:
# <Axes: xlabel='room_type', ylabel='Count'>

# %%
ax = sns.countplot(data=df1, x='neighbourhood_group', hue = 'room_type') #Which neighbour hood has most number of airbnbs
ax.set(xlabel='Neighbourhood Group', ylabel='Number of AirBNBs')
# Out:
# [Text(0.5, 0, 'Neighbourhood Group'), Text(0, 0.5, 'Number of AirBNBs')]

# %%
sns.scatterplot(data = df1, x = 'neighbourhood_group', y = 'price', hue = 'room_type')
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='price'>

# %%
sns.barplot(data = df1, x = 'neighbourhood_group', y = 'price')
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='price'>

# %%
sns.barplot(data = df1, x = 'neighbourhood_group', y = 'price', hue = 'room_type')
# Out:
# <Axes: xlabel='neighbourhood_group', ylabel='price'>

# %%
top_10 = df1[['name', 'host_name','number_of_reviews', 'room_type']]
top_10 = top_10.sort_values(by = 'number_of_reviews', ascending = False ).head(10)
top_10
# Out:
#                                                     name host_name  \
# 11759                            Room near JFK Queen Bed      Dona
# 2031                          Great Bedroom in Manhattan        Jj
# 2030                      Beautiful Bedroom in Manhattan        Jj
# 2015                        Private Bedroom in Manhattan        Jj
# 13495                            Room Near JFK Twin Beds      Dona
# 10623                  Steps away from Laguardia airport      Maya
# 1879            Manhattan Lux Loft.Like.Love.Lots.Look !     Carol
# 20403  Cozy Room Family Home LGA Airport NO CLEANING FEE  Danielle
# 4870                  Private brownstone studio Brooklyn       Asa
# 471                      LG Private Room/Family Friendly     Wanda
#
#        number_of_reviews        room_type
# 11759                629     Private room
# 2031                 607     Private room
# 2030                 597     Private room
# 2015                 594     Private room
# ...

# %%
sns.set(rc={'figure.figsize':(12, 5)})
sns.barplot(x ='name', y = 'number_of_reviews', data = top_10.head(5))
# Out:
# <Axes: xlabel='name', ylabel='number_of_reviews'>

# %%
sns.barplot(x ='host_name', y = 'number_of_reviews', data = top_10)
# Out:
# <Axes: xlabel='host_name', ylabel='number_of_reviews'>
